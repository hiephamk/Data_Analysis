# %% [markdown]
# <a href="https://colab.research.google.com/github/hiephamk/Data_Analysis/blob/Khanh-Chi/Group_HIep_Dan_Chi_Andy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import data_table
url = 'https://raw.githubusercontent.com/hiephamk/Data_Analysis/main/ds_salaries.csv'
salary = pd.read_csv(url,sep = ',')
salary.head(10)
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
# 5       2023               SE              FT         Applied Scientist
# 6       2023               SE              FT         Applied Scientist
# 7       2023               SE              FT            Data Scientist
# 8       2023               SE              FT            Data Scientist
# 9       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# ...

# %%
salary.shape
# Out:
# (3755, 11)

# %%
salary.set_index("work_year")
# Out:
#           experience_level employment_type                 job_title   salary  \
# work_year
# 2023                    SE              FT  Principal Data Scientist    80000
# 2023                    MI              CT               ML Engineer    30000
# 2023                    MI              CT               ML Engineer    25500
# 2023                    SE              FT            Data Scientist   175000
# 2023                    SE              FT            Data Scientist   120000
# ...                    ...             ...                       ...      ...
# 2020                    SE              FT            Data Scientist   412000
# 2021                    MI              FT  Principal Data Scientist   151000
# 2020                    EN              FT            Data Scientist   105000
# 2020                    EN              CT     Business Data Analyst   100000
# 2021                    SE              FT      Data Science Manager  7000000
#
# ...

# %%
salary.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object
